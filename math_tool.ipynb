# %%
import math
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def dtanh(x):
    tmp = np.tanh(x)
    return 1 - tmp * tmp

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-1 * x))

# %%
def dsigmoid(x):
    y = sigmoid(x)
    return y * (1 - y)

# %%
def d_tanh_sigmoid(x):
    y = sigmoid(x)
    d = dtanh(y) * y * (1 - y)
    return d

# %%
def dtanh_sigmoid(x):
    y = sigmoid(x)
    return dtanh(y)

# %%
x = np.linspace(-10, 10, 100)

# %%
plt.plot(x, d_tanh_sigmoid(x), label = 'd_tanh_sigmoid')
plt.plot(x, dtanh_sigmoid(x), label = 'dtanh_sigmoid')
plt.plot(x, sigmoid(x), label = 'simoid')
plt.plot(x, np.tanh(x), label = 'tanh')
plt.legend()
plt.show()

# %%
x = np.linspace(-100, 100, 100)
x = [i for i in x if i != 0]
plt.plot(x, 1 / (1 - np.power(0.9, x)), label = '1/(1+0.9^x)')
#plt.plot(x, 1 / (x), label = '1/x')
plt.legend()
plt.show()

# %%
x = np.linspace(-10, 10, 200)
y = np.linspace(-10, 10, 200)
x = np.arange(-10, 10, 0.1)
y = np.arange(-10, 10, 0.1)
x, y = np.meshgrid(x, y)

# %%
ax = Axes3D(plt.figure())

# %%
def elipse_func(x, y):
    return np.power(x, 2) + np.power(y, 2)

# %%
def dtanh_sigmoid_xy(x, y):
    return dtanh(x) * sigmoid(y)

# %%
#z = elipse_func(x, y)
z = dtanh_sigmoid_xy(x, y)
z
# Out:
# array([[  3.74287929e-13,   4.57156303e-13,   5.58371967e-13, ...,
#           6.81997064e-13,   5.58371967e-13,   4.57156303e-13],
#        [  4.13650159e-13,   5.05233439e-13,   6.17093513e-13, ...,
#           7.53719723e-13,   6.17093513e-13,   5.05233439e-13],
#        [  4.57151714e-13,   5.58366358e-13,   6.81990206e-13, ...,
#           8.32984723e-13,   6.81990206e-13,   5.58366358e-13],
#        ...,
#        [  8.24410932e-09,   1.00693778e-08,   1.22987657e-08, ...,
#           1.50217464e-08,   1.22987657e-08,   1.00693778e-08],
#        [  8.24415739e-09,   1.00694365e-08,   1.22988374e-08, ...,
#           1.50218340e-08,   1.22988374e-08,   1.00694365e-08],
#        [  8.24420090e-09,   1.00694896e-08,   1.22989023e-08, ...,
#           1.50219133e-08,   1.22989023e-08,   1.00694896e-08]])

# %%
ax.plot_surface(x, y, z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, alpha=0.5)
ax.set_xlabel('x label', color='r')
ax.set_ylabel('y label', color='g')
ax.set_zlabel('z label', color='b')
plt.show()
